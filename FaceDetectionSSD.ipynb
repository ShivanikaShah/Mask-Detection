# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip3 install -r 'drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt'
# Out:
# Requirement already satisfied: tensorflow>=2.5.0* in /usr/local/lib/python3.7/dist-packages (from -r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (2.7.0)
# Collecting keras==2.4.3
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: imutils==0.5.4 in /usr/local/lib/python3.7/dist-packages (from -r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 3)) (0.5.4)
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.7/dist-packages (from -r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 4)) (1.19.5)
# Collecting opencv-python==4.5.1.*
#   Downloading opencv_python-4.5.1.48-cp37-cp37m-manylinux2014_x86_64.whl (50.4 MB)
#      |████████████████████████████████| 50.4 MB 16 kB/s
# Collecting matplotlib==3.4.1
#   Downloading matplotlib-3.4.1-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 12.4 MB/s
# Collecting argparse==1.4.0
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Collecting scipy==1.6.2
#   Downloading scipy-1.6.2-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 92 kB/s
# Collecting scikit-learn==0.24.1
#   Downloading scikit_learn-0.24.1-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 108 kB/s
# Collecting pillow>=8.3.2
#   Downloading Pillow-8.4.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 20.4 MB/s
# Collecting streamlit==0.79.0
#   Downloading streamlit-0.79.0-py2.py3-none-any.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 32.2 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.4.3->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 2)) (3.13)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4.1->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4.1->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4.1->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4.1->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 6)) (2.4.7)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.1->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 9)) (1.1.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.0.0-py3-none-any.whl (14 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 47.1 MB/s
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (1.5.1)
# Collecting gitpython
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 46.7 MB/s
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (3.17.3)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (1.1.5)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.8.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (21.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (2.23.0)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (4.2.4)
# Collecting watchdog
#   Downloading watchdog-2.1.6-py3-none-manylinux2014_x86_64.whl (76 kB)
#      |████████████████████████████████| 76 kB 4.9 MB/s
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 28.8 MB/s
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (4.1.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.10.2)
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (2.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (3.3.0)
# Collecting tensorflow>=2.5.0*
#   Downloading tensorflow-2.7.0rc1-cp37-cp37m-manylinux2010_x86_64.whl (489.5 MB)
#      |████████████████████████████████| 489.5 MB 32 kB/s
#   Downloading tensorflow-2.7.0rc0-cp37-cp37m-manylinux2010_x86_64.whl (489.5 MB)
#      |████████████████████████████████| 489.5 MB 1.2 kB/s
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (1.41.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (1.6.3)
# Collecting tensorflow>=2.5.0*
#   Downloading tensorflow-2.6.2-cp37-cp37m-manylinux2010_x86_64.whl (458.3 MB)
#      |████████████████████████████████| 458.3 MB 13 kB/s
#   Downloading tensorflow-2.6.1-cp37-cp37m-manylinux2010_x86_64.whl (458.3 MB)
#      |████████████████████████████████| 458.3 MB 13 kB/s
# Collecting tensorflow-estimator<2.7
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 57.5 MB/s
# Collecting tensorflow>=2.5.0*
#   Downloading tensorflow-2.6.0-cp37-cp37m-manylinux2010_x86_64.whl (458.3 MB)
#      |████████████████████████████████| 458.3 MB 13 kB/s
#   Downloading tensorflow-2.6.0rc2-cp37-cp37m-manylinux2010_x86_64.whl (458.3 MB)
#      |████████████████████████████████| 458.3 MB 2.6 kB/s
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (0.12.0)
# Collecting tensorflow>=2.5.0*
#   Downloading tensorflow-2.6.0rc1-cp37-cp37m-manylinux2010_x86_64.whl (458.2 MB)
#      |████████████████████████████████| 458.2 MB 14 kB/s
#   Downloading tensorflow-2.6.0rc0-cp37-cp37m-manylinux2010_x86_64.whl (456.5 MB)
#      |████████████████████████████████| 456.5 MB 16 kB/s
#   Downloading tensorflow-2.5.2-cp37-cp37m-manylinux2010_x86_64.whl (454.4 MB)
#      |████████████████████████████████| 454.4 MB 24 kB/s
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 19.3 MB/s
# Collecting tensorflow-estimator<2.6.0,>=2.5.0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 41.7 MB/s
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 40.2 MB/s
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.11.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (2.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (2.11.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras==2.4.3->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 2)) (1.5.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.0->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (2018.9)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (7.6.5)
# Collecting ipykernel>=5.1.2
#   Downloading ipykernel-6.5.0-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 50.7 MB/s
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (5.1.1)
# Collecting ipython<8.0,>=7.23.1
#   Downloading ipython-7.29.0-py3-none-any.whl (790 kB)
#      |████████████████████████████████| 790 kB 45.3 MB/s
# Requirement already satisfied: argcomplete>=1.12.3 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (1.12.3)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (5.3.5)
# Requirement already satisfied: importlib-metadata<5 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (4.8.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (3.6.0)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.22-py3-none-any.whl (374 kB)
#      |████████████████████████████████| 374 kB 47.7 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (4.8.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (3.5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (4.9.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.2.5)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.0*->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (5.3.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (5.6.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (4.1.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.8.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.79.0->-r drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject/requirements.txt (line 11)) (0.5.1)
# Building wheels for collected packages: wrapt, blinker
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68722 sha256=41190c9885b557eed786f646d665413f1205fa749682ba871bc9eb5b1a35def0
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=024f2024e7b6b70bacec7f77a5eecdc4513d7e8ee10e9cab5baffab8946f039b
#   Stored in directory: /root/.cache/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# Successfully built wrapt blinker
# Installing collected packages: typing-extensions, prompt-toolkit, ipython, ipykernel, smmap, grpcio, gitdb, wrapt, watchdog, validators, threadpoolctl, tensorflow-estimator, scipy, pydeck, pillow, keras-nightly, gitpython, flatbuffers, blinker, base58, tensorflow, streamlit, scikit-learn, opencv-python, matplotlib, keras, argparse
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Attempting uninstall: ipython
#     Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.41.1
#     Uninstalling grpcio-1.41.1:
#       Successfully uninstalled grpcio-1.41.1
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.13.3
#     Uninstalling wrapt-1.13.3:
#       Successfully uninstalled wrapt-1.13.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.7.0
#     Uninstalling keras-2.7.0:
#       Successfully uninstalled keras-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.22 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.5.0 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.29.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed argparse-1.4.0 base58-2.1.1 blinker-1.4 flatbuffers-1.12 gitdb-4.0.9 gitpython-3.1.24 grpcio-1.34.1 ipykernel-6.5.0 ipython-7.29.0 keras-2.4.3 keras-nightly-2.5.0.dev2021032900 matplotlib-3.4.1 opencv-python-4.5.1.48 pillow-8.4.0 prompt-toolkit-3.0.22 pydeck-0.7.1 scikit-learn-0.24.1 scipy-1.6.2 smmap-5.0.0 streamlit-0.79.0 tensorflow-2.5.2 tensorflow-estimator-2.5.0 threadpoolctl-3.0.0 typing-extensions-3.7.4.3 validators-0.18.2 watchdog-2.1.6 wrapt-1.12.1

# %%
import streamlit as st
from PIL import Image, ImageEnhance
import numpy as np
import cv2
import os

from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
from google.colab.patches import cv2_imshow

path = 'drive/MyDrive/Colab Notebooks/FaceMaskDetectionProject'

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.2

# %%
def load_faces(directory):
  imgs=[]
  for i,filename in os.listdir(directory):
    print(i)
    if(i<5):
      img = cv2.imread(directory+filename)
      imgs.append(image)
  return imgs

def mask_image(image):
    global RGB_img
    # load our serialized face detector model from disk
    print("[INFO] loading face detector model...")
    prototxtPath = path+"/face_detector/deploy.prototxt"
    weightsPath = path+"/face_detector/res10_300x300_ssd_iter_140000.caffemodel"
    net = cv2.dnn.readNet(prototxtPath, weightsPath)

    # load the face mask detector model from disk
    print("[INFO] loading face mask detector model...")
    model = load_model(path+"/mask_detector.model")

    # load the input image from disk and grab the image spatial
    # dimensions
    #image = cv2.imread(path+"/images/pic2.jpg")
    #image = cv2.imread(path+"/dataset/without_mask/without_mask_630.jpg")
    (h, w) = image.shape[:2]

    # construct a blob from the image
    blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300),
                                 (104.0, 177.0, 123.0))

    # pass the blob through the network and obtain the face detections
    print("[INFO] computing face detections...")
    net.setInput(blob)
    detections = net.forward()

    # loop over the detections
    for i in range(0, detections.shape[2]):
        # extract the confidence (i.e., probability) associated with
        # the detection
        confidence = detections[0, 0, i, 2]

        # filter out weak detections by ensuring the confidence is
        # greater than the minimum confidence
        if confidence > 0.5:
            # compute the (x, y)-coordinates of the bounding box for
            # the object
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # ensure the bounding boxes fall within the dimensions of
            # the frame
            (startX, startY) = (max(0, startX), max(0, startY))
            (endX, endY) = (min(w - 1, endX), min(h - 1, endY))

            # extract the face ROI, convert it from BGR to RGB channel
            # ordering, resize it to 224x224, and preprocess it
            face = image[startY:endY, startX:endX]
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            face = cv2.resize(face, (224, 224))
            face = img_to_array(face)
            face = preprocess_input(face)
            face = np.expand_dims(face, axis=0)
            
            # pass the face through the model to determine if the face
            # has a mask or not
            (mask, withoutMask) = model.predict(face)[0]

            # determine the class label and color we'll use to draw
            # the bounding box and text
            label = "Mask" if mask > withoutMask else "No Mask"
            color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

            # include the probability in the label
            label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

            # display the label and bounding box rectangle on the output
            # frame
            
            cv2.putText(image, label, (startX, startY - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
            cv2.rectangle(image, (startX, startY), (endX, endY), color, 2)
            cv2_imshow(image)
            RGB_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
#images = load_faces(path+'/dataset/with_mask/')
#images.append(load_faces(path+'/dataset/without_mask/'))
directory = path+"/dataset/with_mask/"
for i in range(1,11):
  img = cv2.imread(path+"/dataset/with_mask/with_mask_"+str(i)+".jpg")
  #print(filename)
  mask_image(img)
  img = cv2.imread(path+"/dataset/without_mask/without_mask_"+str(i)+".jpg")
  mask_image(img)
#img = cv2.imread(path+"/dataset/without_mask/without_mask_630.jpg")
# Out:
# [INFO] loading face detector model...
# [INFO] loading face mask detector model...
# [INFO] computing face detections...
# <PIL.Image.Image image mode=RGB size=525x350 at 0x7F7EF40AF3D0>
# [INFO] loading face detector model...
# [INFO] loading face mask detector model...
# [INFO] computing face detections...
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F7EF3B8D4D0>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F7EF3E9DE90>
# [INFO] loading face detector model...
# [INFO] loading face mask detector model...
# [INFO] computing face detections...
# <PIL.Image.Image image mode=RGB size=201x251 at 0x7F7EF3B8D4D0>
# [INFO] loading face detector model...
# [INFO] loading face mask detector model...
# [INFO] computing face detections...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_467/2419716062.py in <module>
#       7   mask_image(img)
#       8   img = cv2.imread(path+"/dataset/without_mask/without_mask_"+str(i)+".jpg")
# ----> 9   mask_image(img)
#      10 #img = cv2.imread(path+"/dataset/without_mask/without_mask_630.jpg")
#
# /tmp/ipykernel_467/705512971.py in mask_image(image)
#      57             # ordering, resize it to 224x224, and preprocess it
#      58             face = image[startY:endY, startX:endX]
# ---> 59             face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
#      60             face = cv2.resize(face, (224, 224))
#      61             face = img_to_array(face)
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-7m_g9lbm/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
